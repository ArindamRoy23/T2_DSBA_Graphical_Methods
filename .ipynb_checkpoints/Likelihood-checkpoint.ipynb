# %% [markdown]
# ### Testing the ```utils.Filehandling.FileHandlingInterface``` module

# %%
from src.lib.utils.FileHandling.FileHandlingInterface import *
from src.lib.probabilityEstim.Likelihood import *
import matplotlib.pyplot as plt
import logging
import time
import warnings

# %%
numba_logger = logging.getLogger('numba')
numba_logger.setLevel(logging.DEBUG)
warnings.simplefilter("always", RuntimeWarning)

# %%
PASCAL_DEMO_IMAGE_PATH = r"data\Pascal\scribble_annotation\scribble_annotation\demo\2008_003147.jpg"
PASCAL_DEMO_IMAGE_PATH1 = r"data\Pascal\scribble_annotation\scribble_annotation\demo\2010_005258.jpg"

# %%
sample_image = TargetImage(
    PASCAL_DEMO_IMAGE_PATH1              
)

# %%
image_array = sample_image.get_image_array()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 image_array = sample_image.get_image_array()
#
# File ~\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\utils\FileHandling\FileHandlingInterface.py:52, in TargetImage.get_image_array(self)
#      45 def get_image_array(
#      46         self
#      47     ) -> np.ndarray:
#      48     """
#      49     get_image_array(self):
#      50         returns the underlying image as a np.ndarray object
#      51     """
# ---> 52     image_array = JpegImageReader.get_image_array(self) if self.is_jpeg\
#      53             else NIfTIImageReader.get_image_array(self)
#      54     return image_array
#
# File ~\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\utils\FileHandling\FileHandlingProtected.py:133, in JpegImageReader.get_image_array(self)
#     124 def get_image_array(
#     125         self
#     126     ) -> Tensor:
#     127     """
#     128     get_image_tensor(self):
#     129         returns the underlying image as a Tensor object
#     130         IMPORTANT NOTICE: the shape elements should be in
#     131         the following order (n_channels, image_width, image_height)
#     132     """
# --> 133     image = self.__get_file_content()
#     134     image_array = np.asarray(image)
#     135     image_array = image_array.transpose((2, 1, 0))
#
# File ~\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\utils\FileHandling\FileHandlingProtected.py:121, in JpegImageReader.__get_file_content(self)
#     116 """
#     117 __get_file_content(self):
#     118     returns the underlying image as a Image image object
#     119 """
#     120 path = self.path_to_file
# --> 121 image =  Image.open(path)
#     122 return image
#
# File ~\anaconda3\envs\graphical_models\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\Pascal\\scribble_annotation\\scribble_annotation\\demo\\2010_005258.jpg'

# %%
plt.imshow(image_array.transpose((2, 1, 0)))

# %%
PASCAL_DEMO_SCRIBBLE_PATH = r"data\Pascal\scribble_annotation\scribble_annotation\demo\2008_003147.xml"
PASCAL_DEMO_SCRIBBLE_PATH1 = r"data\Pascal\scribble_annotation\scribble_annotation\demo\2010_005258.xml"

# %%
sample_scribble = EncodedScribble(
    PASCAL_DEMO_SCRIBBLE_PATH1
)

# %% [markdown]
# debug values:
#
# *    0 -> No debugging (Default)
# *    1 -> Spatial Kernel
# *    2 -> Chromatic Kernel
# *    3 -> Spatial Kernel Exponent Argument
# *    4 -> Chromatic Kernel Exponent Argument
# *    5 -> Spatial Kernel Normalization Term
# *    7 -> Spatial Kernel Width

# %%
n_classes = sample_scribble.get_n_classes()

# %%
likelihood = Likelihood(n_classes, on_gpu = True, debug = 3)

# %%
time0 = time.time()
fitted_likelihood = likelihood.fit(
    sample_image, 
    sample_scribble
)
print(f"{time.time() - time0}")
# Out:
# 0.6658236980438232

# %%
classes = list(sample_scribble.get_scribble_dictionary().keys())
for dim in range(fitted_likelihood.shape[0]):
    # Create a new figure and axis for each plot
    fig, ax = plt.subplots()
    
    vmin = np.min(fitted_likelihood[dim])
    vmax = np.max(fitted_likelihood[dim])
    im1 = ax.imshow(fitted_likelihood[dim].transpose((1, 0)), cmap='magma', alpha=1.0, vmin=vmin, vmax=vmax)
    
    # Add a title and colorbar legend to the plot
    ax.set_title(classes[dim]) 
    fig.colorbar(im1, ax=ax, label='')
    
    # Plot the image array on the same axis
    im2 = ax.imshow(image_array.transpose((2, 1, 0)), alpha=0.3)
    
    
    # Save the plot as a PNG image file
    fig.savefig(f'./plots/spatialKernel/exponentialArg/plot_{classes[dim]}.png', dpi=300)
    # Show the plot
    plt.show()

# %%
classes = list(sample_scribble.get_scribble_dictionary().keys())
for dim in range(fitted_likelihood.shape[0]):
    # Create a new figure and axis for each plot
    fig, ax = plt.subplots()
    
    vmin = np.min(fitted_likelihood[dim])
    vmax = np.max(fitted_likelihood[dim])
    im1 = ax.imshow(fitted_likelihood[dim].transpose((1, 0)), cmap='magma', alpha=1.0, vmin=vmin, vmax=vmax)
    
    # Add a title and colorbar legend to the plot
    ax.set_title(classes[dim]) 
    fig.colorbar(im1, ax=ax, label='')
    
    # Plot the image array on the same axis
    im2 = ax.imshow(image_array.transpose((2, 1, 0)), alpha=0.3)
    
    
    # Save the plot as a PNG image file
    fig.savefig(f'./plots/spatialKernel/exponentialArg/plot_{classes[dim]}.png', dpi=300)
    # Show the plot
    plt.show()

# %%
classes = list(sample_scribble.get_scribble_dictionary().keys())
for dim in range(fitted_likelihood.shape[0]):
    # Create a new figure and axis for each plot
    fig, ax = plt.subplots()
    
    vmin = np.min(fitted_likelihood[dim])
    vmax = np.max(fitted_likelihood[dim])
    im1 = ax.imshow(fitted_likelihood[dim].transpose((1, 0)), cmap='magma', alpha=1.0, vmin=vmin, vmax=vmax)
    
    # Add a title and colorbar legend to the plot
    ax.set_title(classes[dim]) 
    fig.colorbar(im1, ax=ax, label='')
    
    # Plot the image array on the same axis
    im2 = ax.imshow(image_array.transpose((2, 1, 0)), alpha=0.3)
    
    
    # Save the plot as a PNG image file
    fig.savefig(f'./plots/spatialKernel/exponentialArg/plot_{classes[dim]}.png', dpi=300)
    # Show the plot
    plt.show()

# %%
fitted_likelihood[0].max()
# Out:
# 0.0005576568736303904
