# %%
from src.lib.utils.FileHandling.FileHandlingInterface import *
from src.lib.SVCDSeg.SVCDSeg import *
import matplotlib.pyplot as plt
import logging
import time
import warnings

# %%
numba_logger = logging.getLogger('numba')
numba_logger.setLevel(logging.DEBUG)
warnings.simplefilter("always", RuntimeWarning)

# %%
PASCAL_DEMO_IMAGE_PATH = r"src\data\demoPascal\2008_003147.jpg"
PASCAL_DEMO_IMAGE_PATH1 = r"src\data\demoPascal\2010_005258.jpg"

# %%
PASCAL_DEMO_SCRIBBLE_PATH = r"src\data\demoPascal\2008_003147.xml"
PASCAL_DEMO_SCRIBBLE_PATH1 = r"src\data\demoPascal\2010_005258.xml"

# %%
sample_image = TargetImage(
    PASCAL_DEMO_IMAGE_PATH1              
)

# %%
sample_scribble = EncodedScribble(
    PASCAL_DEMO_SCRIBBLE_PATH1
)

# %%
n_classes = sample_scribble.get_n_classes()

# %%
segmenter = SVCDSeg(
    n_classes,
    debug = 0
)

# %%
fitted_segmentation = segmenter.fit(
    sample_image,
    sample_scribble 
)
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:101: RuntimeWarning: invalid value encountered in divide
#   norm_xi = np.sqrt(xi[0]**2 + xi[1]**2) / fitted_prior
# C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   1%|▊                                                                                 | 1/100 [00:00<00:31,  3.12it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   2%|█▋                                                                                | 2/100 [00:00<00:29,  3.35it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   3%|██▍                                                                               | 3/100 [00:00<00:26,  3.68it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   4%|███▎                                                                              | 4/100 [00:01<00:27,  3.54it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   5%|████                                                                              | 5/100 [00:01<00:26,  3.56it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   6%|████▉                                                                             | 6/100 [00:01<00:27,  3.40it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   7%|█████▋                                                                            | 7/100 [00:02<00:26,  3.45it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   8%|██████▌                                                                           | 8/100 [00:02<00:25,  3.55it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#   9%|███████▍                                                                          | 9/100 [00:02<00:26,  3.40it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  10%|████████                                                                         | 10/100 [00:02<00:26,  3.37it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  11%|████████▉                                                                        | 11/100 [00:03<00:25,  3.45it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  12%|█████████▋                                                                       | 12/100 [00:03<00:25,  3.44it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  13%|██████████▌                                                                      | 13/100 [00:03<00:26,  3.27it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  14%|███████████▎                                                                     | 14/100 [00:04<00:25,  3.36it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  15%|████████████▏                                                                    | 15/100 [00:04<00:24,  3.46it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  16%|████████████▉                                                                    | 16/100 [00:04<00:23,  3.50it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  17%|█████████████▊                                                                   | 17/100 [00:04<00:23,  3.48it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  18%|██████████████▌                                                                  | 18/100 [00:05<00:23,  3.56it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  19%|███████████████▍                                                                 | 19/100 [00:05<00:23,  3.45it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  20%|████████████████▏                                                                | 20/100 [00:05<00:24,  3.32it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  21%|█████████████████                                                                | 21/100 [00:06<00:24,  3.28it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  22%|█████████████████▊                                                               | 22/100 [00:06<00:23,  3.35it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  23%|██████████████████▋                                                              | 23/100 [00:06<00:23,  3.21it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  24%|███████████████████▍                                                             | 24/100 [00:07<00:24,  3.16it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  25%|████████████████████▎                                                            | 25/100 [00:07<00:23,  3.18it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  26%|█████████████████████                                                            | 26/100 [00:07<00:22,  3.23it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  27%|█████████████████████▊                                                           | 27/100 [00:08<00:22,  3.25it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  28%|██████████████████████▋                                                          | 28/100 [00:08<00:21,  3.28it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  29%|███████████████████████▍                                                         | 29/100 [00:08<00:22,  3.11it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  30%|████████████████████████▎                                                        | 30/100 [00:08<00:22,  3.12it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  31%|█████████████████████████                                                        | 31/100 [00:09<00:22,  3.09it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  32%|█████████████████████████▉                                                       | 32/100 [00:09<00:22,  3.02it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  33%|██████████████████████████▋                                                      | 33/100 [00:09<00:21,  3.13it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  34%|███████████████████████████▌                                                     | 34/100 [00:10<00:20,  3.24it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  35%|████████████████████████████▎                                                    | 35/100 [00:10<00:21,  3.06it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  36%|█████████████████████████████▏                                                   | 36/100 [00:10<00:20,  3.14it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  37%|█████████████████████████████▉                                                   | 37/100 [00:11<00:19,  3.19it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  38%|██████████████████████████████▊                                                  | 38/100 [00:11<00:20,  3.08it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  39%|███████████████████████████████▌                                                 | 39/100 [00:11<00:18,  3.22it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  40%|████████████████████████████████▍                                                | 40/100 [00:12<00:18,  3.29it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  41%|█████████████████████████████████▏                                               | 41/100 [00:12<00:17,  3.29it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  42%|██████████████████████████████████                                               | 42/100 [00:12<00:18,  3.19it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  43%|██████████████████████████████████▊                                              | 43/100 [00:13<00:17,  3.29it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  44%|███████████████████████████████████▋                                             | 44/100 [00:13<00:16,  3.32it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  45%|████████████████████████████████████▍                                            | 45/100 [00:13<00:16,  3.26it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  46%|█████████████████████████████████████▎                                           | 46/100 [00:13<00:16,  3.25it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  47%|██████████████████████████████████████                                           | 47/100 [00:14<00:16,  3.30it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  48%|██████████████████████████████████████▉                                          | 48/100 [00:14<00:15,  3.26it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  49%|███████████████████████████████████████▋                                         | 49/100 [00:14<00:15,  3.26it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  50%|████████████████████████████████████████▌                                        | 50/100 [00:15<00:15,  3.26it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  51%|█████████████████████████████████████████▎                                       | 51/100 [00:15<00:15,  3.17it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  52%|██████████████████████████████████████████                                       | 52/100 [00:15<00:15,  3.18it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  53%|██████████████████████████████████████████▉                                      | 53/100 [00:16<00:14,  3.32it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  54%|███████████████████████████████████████████▋                                     | 54/100 [00:16<00:13,  3.41it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  55%|████████████████████████████████████████████▌                                    | 55/100 [00:16<00:13,  3.33it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [00:16<00:12,  3.42it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  57%|██████████████████████████████████████████████▏                                  | 57/100 [00:17<00:12,  3.37it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  58%|██████████████████████████████████████████████▉                                  | 58/100 [00:17<00:12,  3.26it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  59%|███████████████████████████████████████████████▊                                 | 59/100 [00:17<00:12,  3.34it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  60%|████████████████████████████████████████████████▌                                | 60/100 [00:18<00:12,  3.27it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  61%|█████████████████████████████████████████████████▍                               | 61/100 [00:18<00:12,  3.17it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  62%|██████████████████████████████████████████████████▏                              | 62/100 [00:18<00:11,  3.27it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  63%|███████████████████████████████████████████████████                              | 63/100 [00:19<00:10,  3.41it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  64%|███████████████████████████████████████████████████▊                             | 64/100 [00:19<00:10,  3.45it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  65%|████████████████████████████████████████████████████▋                            | 65/100 [00:19<00:10,  3.39it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  66%|█████████████████████████████████████████████████████▍                           | 66/100 [00:19<00:09,  3.43it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  67%|██████████████████████████████████████████████████████▎                          | 67/100 [00:20<00:09,  3.36it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  68%|███████████████████████████████████████████████████████                          | 68/100 [00:20<00:09,  3.23it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  69%|███████████████████████████████████████████████████████▉                         | 69/100 [00:20<00:09,  3.32it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  70%|████████████████████████████████████████████████████████▋                        | 70/100 [00:21<00:09,  3.23it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  71%|█████████████████████████████████████████████████████████▌                       | 71/100 [00:21<00:08,  3.35it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  72%|██████████████████████████████████████████████████████████▎                      | 72/100 [00:21<00:08,  3.30it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  73%|███████████████████████████████████████████████████████████▏                     | 73/100 [00:22<00:08,  3.33it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  74%|███████████████████████████████████████████████████████████▉                     | 74/100 [00:22<00:08,  3.20it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  75%|████████████████████████████████████████████████████████████▊                    | 75/100 [00:22<00:07,  3.25it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  76%|█████████████████████████████████████████████████████████████▌                   | 76/100 [00:23<00:07,  3.37it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  77%|██████████████████████████████████████████████████████████████▎                  | 77/100 [00:23<00:06,  3.35it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  78%|███████████████████████████████████████████████████████████████▏                 | 78/100 [00:23<00:06,  3.25it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  79%|███████████████████████████████████████████████████████████████▉                 | 79/100 [00:23<00:06,  3.31it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  80%|████████████████████████████████████████████████████████████████▊                | 80/100 [00:24<00:06,  3.24it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  81%|█████████████████████████████████████████████████████████████████▌               | 81/100 [00:24<00:05,  3.30it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  82%|██████████████████████████████████████████████████████████████████▍              | 82/100 [00:24<00:05,  3.32it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  83%|███████████████████████████████████████████████████████████████████▏             | 83/100 [00:25<00:05,  3.38it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  84%|████████████████████████████████████████████████████████████████████             | 84/100 [00:25<00:04,  3.36it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  85%|████████████████████████████████████████████████████████████████████▊            | 85/100 [00:25<00:04,  3.40it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  86%|█████████████████████████████████████████████████████████████████████▋           | 86/100 [00:26<00:04,  3.33it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  87%|██████████████████████████████████████████████████████████████████████▍          | 87/100 [00:26<00:03,  3.31it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  88%|███████████████████████████████████████████████████████████████████████▎         | 88/100 [00:26<00:03,  3.28it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  89%|████████████████████████████████████████████████████████████████████████         | 89/100 [00:26<00:03,  3.36it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  90%|████████████████████████████████████████████████████████████████████████▉        | 90/100 [00:27<00:03,  3.27it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  91%|█████████████████████████████████████████████████████████████████████████▋       | 91/100 [00:27<00:02,  3.37it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  92%|██████████████████████████████████████████████████████████████████████████▌      | 92/100 [00:27<00:02,  3.43it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  93%|███████████████████████████████████████████████████████████████████████████▎     | 93/100 [00:28<00:02,  3.41it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  94%|████████████████████████████████████████████████████████████████████████████▏    | 94/100 [00:28<00:01,  3.23it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  95%|████████████████████████████████████████████████████████████████████████████▉    | 95/100 [00:28<00:01,  3.24it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  96%|█████████████████████████████████████████████████████████████████████████████▊   | 96/100 [00:29<00:01,  3.30it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  97%|██████████████████████████████████████████████████████████████████████████████▌  | 97/100 [00:29<00:00,  3.20it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  98%|███████████████████████████████████████████████████████████████████████████████▍ | 98/100 [00:29<00:00,  3.24it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
#  99%|████████████████████████████████████████████████████████████████████████████████▏| 99/100 [00:30<00:00,  3.16it/s]C:\Users\lollo\Desktop\GM\T2_DSBA_Graphical_Methods\src\lib\SVCDSeg\SVCDSeg.py:137: RuntimeWarning: divide by zero encountered in divide
#   theta = 1 / p * np.take_along_axis(sum_vecs, indices=pn, axis=0)
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:30<00:00,  3.30it/s]

# %%
classes = list(sample_scribble.get_scribble_dictionary().keys())
for dim in range(fitted_segmentation.shape[0]):
    # Create a new figure and axis for each plot
    fig, ax = plt.subplots()
    
    vmin = np.min(fitted_segmentation[dim])
    vmax = np.max(fitted_segmentation[dim])
    im1 = ax.imshow(fitted_segmentation[dim].transpose((1, 0)), cmap='magma', alpha=1.0, vmin=vmin, vmax=vmax)
    
    # Add a title and colorbar legend to the plot
    ax.set_title(classes[dim]) 
    fig.colorbar(im1, ax=ax, label='')
    
    # Plot the image array on the same axis
    #im2 = ax.imshow(image_array.transpose((2, 1, 0)), alpha=0.3)
    
    
    # Save the plot as a PNG image file
    #fig.savefig(f'plots/2010/notNormalized10/plot_{classes[dim]}.png', dpi=300)
    # Show the plot
    plt.show()

# %%
energy_list = segmenter.theta_history

# %%
np.argwhere(np.isnan(energy_list[1]))
# Out:
# array([[  0,  20, 172],
#        [  0,  27, 179],
#        [  0,  27, 180],
#        ...,
#        [  2, 465, 248],
#        [  2, 466, 204],
#        [  2, 466, 248]], dtype=int64)
